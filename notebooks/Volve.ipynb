# %% [markdown]
# # MDD with physics-aware factorization-based low-rank regularization
#
# The purpose of this notebook is to demonstrate the efficiency of the proposed method on field data. It also reproduces the last example in the paper

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import norm
from numpy import inf

# %% [markdown]
# Define functions implementing the reciprocal low-rank factorization: $X=QQ^T$, i.e., in this case, the complex matrix $X$ is represented by the product of one low-rank matrix $Q$ and its transpose.

# %%
def diffQQt(xs, ia, ib):
    xs = xs[0]
    r = ia.dot(xs@xs.T) - ib
    return r

def gradQQt(xs, ir, ia):
    
    xs = xs[0] 
    AhR = ia.T.conj().dot(ir)
    
    dd = (AhR +  AhR.T).dot(xs.conj())   

    return dd

# %% [markdown]
# Define the proximal operator of Frobenious norm:

# %%
def prox_Fro(v, t, lam):

    nv = norm(v,ord='fro')
    v  = v/(1+lam/t)
    
    nnv = norm(v, ord='fro')
    
    return v, nv**2 * 0.5, nnv**2 * 0.5

# %% [markdown]
# Below define the main function to solve the proposed MDD in an alternating style

# %%
def ipalm(grads, proxs, tau_guess, inc, diff, argv, ia, ib, xs0): 
    
    nblocks=len(grads)
    
    xs1=list(xs0)
    xs2=list(xs0)
    
    it=0 
    lam = argv.lam

    nv, nnv = np.zeros(nblocks), np.zeros(nblocks)

    total_msf_old = inf
    
    while it < argv.nit: # and err > tol: 
        reg_msf = 0.0    
        #compute inertial coefficients
        if 0 == argv.inertia: 
            inertia = it/(it+3.0)
        else:
            inertia = argv.inertia
        
        for i in range(nblocks):

            yi = xs1[i] + inertia * (xs1[i] - xs0[i])
            zi = xs1[i] + inertia * (xs1[i] - xs0[i])
             
            xs2[i] = zi
    
            # Estimate the resuial and gradient with the current x
            res = diff(xs2, ia, ib)
            data_msf_cur = 0.5*norm(res, ord='fro')**2 
            gg = grads[i](xs2, res, ia)
                        
            ############################################################## 

            cnt = 0
            while(True):           
    
                tau = tau_guess[i] * inc[i]**cnt
                # print(cnt, tau) 
                y_tmp = yi - 1.0/tau * gg
                
                # x_new, nv[i], nnv[i] = proxs[i](y_tmp, tau, lam[i])
                x_new, nv[i], nnv[i] = proxs[i](y_tmp, tau, lam[i])
                xs2[i] = x_new
                res = diff(xs2, ia, ib)

                data_msf_new = 0.5*norm(res, ord='fro')**2 
                # F(P(y_k))<Q(P(y_k), y_k)
                if data_msf_new < data_msf_cur + 0.5 * ( norm(x_new - y_tmp, ord='fro')**2 * tau - norm(gg, ord='fro')**2 / tau ) or cnt > 5: ## debug ? cnt>20
                    break
                cnt += 1
            
            # tau_guess[i] = tau
            reg_msf += nv[i]*lam[i]/tau

        total_msf_cur = reg_msf + data_msf_cur
        
        if argv.verbose:
            print("%15.3f%18d"%(total_msf_cur,cnt+1), end='', flush=True)
            for i in range(nblocks):
                print("%15.3f%15.3f"%(nv[i], nnv[i]), end='', flush=True)
            print("\n")
        
        if abs(total_msf_cur/total_msf_old-1.0) < argv.tol:
       
            break
        
        total_msf_old = total_msf_cur
     
        xs0 = list(xs1)
        xs1 = list(xs2)
        it+=1 
        
    
    return xs1

# %% [markdown]
# ## Data loading

# %%
dat = np.load('../data/pup_pdown_volve.npz', allow_pickle=True)

pup_f   = dat['pup']

pdown_f = dat['pdown']

nt = 3000

# %%
energy = [np.linalg.norm(ipdown, 'fro') for ipdown in pdown_f]

# %%
# ifstart and ifend can be determined from the figure below.
plt.yscale("log")
plt.plot(energy)
plt.grid()

# %%
ns, nr = pdown_f[0].shape

# %% [markdown]
# ## MDD with the reciprocal low-rank factorization and different $n_r/n_k$

# %%
gradlist=[gradQQt]
proxlist=[prox_Fro]
inc = [2.0]

class args:
    lam = [0.1,]
    nit = 200000
    inertia = 0
    verbose = False
    tol = 1e-7

ifstart, ifend = 0, 360

ret = []

for nk in [nr//3, nr//4, nr//5, nr//10]:

    for idx in range(ifstart, ifend):
    
        ia = pdown_f[idx]
        ib = pup_f[idx]
    
        x0 = np.eye(nr, nk) +  np.eye(nr, nk)*1j
    
        tau_guess = [norm(ia, 'fro')**2]
        
        x1 = ipalm(gradlist, proxlist, tau_guess, inc, diffQQt, args, ia, ib, [x0,])
        
        ret.append(x1[0])

# %%
def q2x(ret):
    
    ret = np.array(ret)
    ret = np.matmul(ret, ret.transpose(0,2,1))
    g = np.zeros((ifend, nr, nr))*1j
    g[ifstart:] = ret
    g = np.fft.irfft(g, n=nt, axis=0)
    return g

# %%
fig, axs = plt.subplots(2,2, figsize=(10,12))

pclip = 0.15

aspect = 0.2

nnt = 1251

g1 = q2x(ret[:ifend])
dat = g1[:nnt, nr//2] 
cc = np.abs(dat).max()
axs[0][0].imshow(dat, aspect=aspect, vmin=-cc*pclip, vmax=cc*pclip, cmap="gray")
title = 'n/k=3'
axs[0][0].set_title(title)

g1 = q2x(ret[ifend:2*ifend])
dat = g1[:nnt, nr//2]
cc = np.abs(dat).max()
axs[0][1].imshow(dat, aspect=aspect, vmin=-cc*pclip, vmax=cc*pclip, cmap="gray")
title = 'n/k=4'
axs[0][1].set_title(title)

g1 = q2x(ret[2*ifend:3*ifend])
dat = g1[:nnt, nr//2]
cc = np.abs(dat).max()
axs[1][0].imshow(dat, aspect=aspect, vmin=-cc*pclip, vmax=cc*pclip, cmap="gray")
title = 'n/k=5'
axs[1][0].set_title(title)

g1 = q2x(ret[3*ifend:])
dat = g1[:nnt, nr//2]
cc = np.abs(dat).max()
axs[1][1].imshow(dat, aspect=aspect, vmin=-cc*pclip, vmax=cc*pclip, cmap="gray")
title = 'n/k=10'
axs[1][1].set_title(title)
# Out:
# Text(0.5, 1.0, 'n/k=10')
